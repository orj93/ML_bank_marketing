# %%
import pandas as pd
X_train = pd.read_csv("X_train_scal.csv")
X_test = pd.read_csv("X_test_scal.csv")
X_train
# Out:
#             age  job   marital  education  default  housing  loan  contact  \
# 0      0.111111  0.3  0.333333   0.500000      0.0      1.0   0.0      1.0
# 1      0.135802  0.2  0.666667   0.833333      0.0      0.0   0.0      1.0
# 2      0.234568  0.5  0.333333   0.500000      0.0      0.0   0.0      0.0
# 3      0.333333  0.3  0.666667   0.500000      0.0      1.0   0.0      1.0
# 4      0.172840  0.6  0.666667   0.166667      0.0      0.0   0.0      1.0
# ...         ...  ...       ...        ...      ...      ...   ...      ...
# 32661  0.333333  0.9  0.666667   0.833333      0.0      1.0   0.0      1.0
# 32662  0.160494  0.1  0.333333   0.166667      0.0      1.0   0.0      1.0
# 32663  0.234568  0.6  0.333333   0.833333      0.0      0.0   0.0      1.0
# 32664  0.234568  0.3  0.333333   0.500000      0.0      0.0   1.0      1.0
# 32665  0.061728  0.4  0.666667   0.500000      0.0      0.0   0.0      0.0
#
#           month  day_of_week  duration  campaign     pdays  previous  \
# 0      0.000000         1.00  0.002620  0.500000  1.000000  0.000000
# 1      0.222222         0.25  0.008335  0.142857  1.000000  0.000000
# 2      0.222222         0.75  0.020957  0.000000  1.000000  0.000000
# 3      0.000000         0.00  0.127649  0.071429  1.000000  0.142857
# 4      0.000000         0.50  0.021434  0.000000  1.000000  0.000000
# ...         ...          ...       ...       ...       ...       ...
# 32661  0.000000         1.00  0.050012  0.071429  1.000000  0.000000
# 32662  0.000000         1.00  0.100976  0.000000  1.000000  0.000000
# 32663  0.111111         0.25  0.124315  0.000000  0.006006  0.285714
# 32664  0.555556         0.00  0.031198  0.000000  1.000000  0.000000
# 32665  0.222222         0.75  0.019767  0.000000  1.000000  0.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# 0          0.333333        0.269680       0.192469   0.139651     0.512287
# 1          1.000000        0.669135       0.338912   0.980957     1.000000
# 2          1.000000        0.669135       0.338912   0.982090     1.000000
# 3          0.333333        0.269680       0.192469   0.138291     0.512287
# 4          0.333333        0.269680       0.192469   0.158694     0.512287
# ...             ...             ...            ...        ...          ...
# 32661      0.333333        0.269680       0.192469   0.139651     0.512287
# 32662      0.333333        0.269680       0.192469   0.153933     0.512287
# 32663      0.354167        0.722525       0.460251   0.023351     0.105860
# 32664      0.687500        0.389322       0.368201   0.806393     0.877883
# 32665      1.000000        0.669135       0.338912   0.981410     1.000000
#
# [32666 rows x 19 columns]

# %%
X_test
# Out:
#            age  job   marital  education  default  housing  loan  contact  \
# 0     0.259259  0.3  0.333333   0.000000      0.0      1.0   0.0      1.0
# 1     0.283951  0.4  0.333333   0.000000      0.0      1.0   0.0      0.0
# 2     0.234568  0.8  0.333333   0.666667      0.0      0.0   1.0      1.0
# 3     0.185185  0.4  0.333333   0.666667      0.0      0.0   0.0      1.0
# 4     0.320988  0.3  0.333333   0.500000      0.0      0.0   0.0      1.0
# ...        ...  ...       ...        ...      ...      ...   ...      ...
# 8162  0.209877  0.4  0.666667   0.666667      0.0      0.0   0.0      0.0
# 8163  0.271605  0.4  0.333333   0.833333      0.0      1.0   0.0      1.0
# 8164  0.283951  0.3  0.333333   0.000000      0.0      0.0   0.0      1.0
# 8165  0.172840  0.4  0.666667   0.833333      0.0      0.0   0.0      1.0
# 8166  0.086420  0.3  0.333333   0.666667      0.0      0.0   0.0      1.0
#
#          month  day_of_week  duration  campaign  pdays  previous  \
# 0     0.000000         0.50  0.023815  0.000000    1.0  0.000000
# 1     0.000000         0.75  0.036437  0.000000    1.0  0.000000
# 2     0.222222         0.00  0.051441  0.285714    1.0  0.000000
# 3     0.222222         0.50  0.117885  0.071429    1.0  0.000000
# 4     0.888889         0.25  0.144796  0.000000    1.0  0.142857
# ...        ...          ...       ...       ...    ...       ...
# 8162  0.000000         0.50  0.006430  0.000000    1.0  0.000000
# 8163  0.333333         0.00  0.013575  0.000000    1.0  0.000000
# 8164  0.000000         0.75  0.024768  0.000000    1.0  0.000000
# 8165  0.555556         0.50  0.088593  0.000000    1.0  0.000000
# 8166  0.888889         0.75  0.082877  0.071429    1.0  0.000000
#
#       emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# 0         0.333333        0.269680       0.192469   0.158694     0.512287
# 1         0.937500        0.698753       0.602510   0.958059     0.859735
# 2         1.000000        0.669135       0.338912   0.980730     1.000000
# 3         1.000000        0.669135       0.338912   0.981410     1.000000
# 4         0.333333        0.340608       0.154812   0.185672     0.512287
# ...            ...             ...            ...        ...          ...
# 8162      0.937500        0.698753       0.602510   0.957833     0.859735
# 8163      1.000000        0.484412       0.615063   0.981864     1.000000
# 8164      0.333333        0.269680       0.192469   0.143278     0.512287
# 8165      0.000000        0.174591       0.866109   0.018590     0.203781
# 8166      0.333333        0.340608       0.154812   0.175924     0.512287
#
# [8167 rows x 19 columns]

# %%
y_train = pd.read_csv("y_train.csv")
y_test = pd.read_csv("y_test.csv")
y_test
# Out:
#       y
# 0     0
# 1     0
# 2     0
# 3     0
# 4     1
# ...  ..
# 8162  0
# 8163  0
# 8164  0
# 8165  1
# 8166  0
#
# [8167 rows x 1 columns]

# %%
y_train = y_train.squeeze()

# %%
y_train
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 32661    0
# 32662    0
# 32663    1
# 32664    0
# 32665    0
# Name: y, Length: 32666, dtype: int64

# %%
y_test = y_test.squeeze()
y_test
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 8162    0
# 8163    0
# 8164    0
# 8165    1
# 8166    0
# Name: y, Length: 8167, dtype: int64

# %%
from pickle import dump, load
from sklearn.feature_selection import f_classif, SelectKBest
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

accs = []
for p in [1, 0.8, 0.7, 0.6, 0.5]:
    selection_model = SelectKBest(f_classif, k = int(len(X_train.columns) * p))
    selection_model.fit(X_train, y_train)

    ix = selection_model.get_support()
    train_sel = pd.DataFrame(selection_model.transform(X_train), columns = X_train.columns.values[ix])


    model = LogisticRegression(random_state = 14)
    model.fit(train_sel, y_train)
    y_pred = model.predict(train_sel)
    acc = accuracy_score(y_train, y_pred)
    accs.append(acc)

best_acc = accs.index(max(accs))

# %%
best_acc
# Out:
# 3

# %%
selection_model = SelectKBest(f_classif, k = 12)
selection_model.fit(X_train, y_train)
# Out:
# SelectKBest(k=12)

# %%
ix = selection_model.get_support()
X_train_sel = pd.DataFrame(selection_model.transform(X_train), columns = X_train.columns.values[ix])
X_test_sel = pd.DataFrame(selection_model.transform(X_test), columns = X_test.columns.values[ix])
model = LogisticRegression(random_state = 14)
model.fit(X_train_sel, y_train)
# Out:
# LogisticRegression(random_state=14)

# %%
y_pred = model.predict(X_train_sel)
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_train, y_pred)
# Out:
# 0.909692034531317

# %%
from sklearn.model_selection import GridSearchCV

hyperparams = {
    "penalty": ["l1", None, "l2"],
    "dual": [True, False],
    "C": [0.001, 0.01, 0.1, 1, 10, 100],
    'solver': ['lbfgs', 'liblinear', 'newton-cg',      
                'newton-cholesky', 'sag', 'saga'],
    'random_state': [14]
}

grid = GridSearchCV(model, hyperparams, cv = 5)
grid
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(random_state=14),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'dual': [True, False], 'penalty': ['l1', None, 'l2'],
#                          'random_state': [14],
#                          'solver': ['lbfgs', 'liblinear', 'newton-cg',
#                                     'newton-cholesky', 'sag', 'saga']})

# %%
grid.fit(X_train_sel, y_train)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1358, in fit
#     self.coef_, self.intercept_, n_iter_ = _fit_liblinear(
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 974, in _fit_liblinear
#     solver_type = _get_liblinear_solver_type(multi_class, penalty, loss, dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 830, in _get_liblinear_solver_type
#     raise ValueError('Unsupported set of arguments: %s, '
# ValueError: Unsupported set of arguments: The combination of penalty='l1' and loss='logistic_regression' are not supported when dual=True, Parameters: penalty='l1', loss='logistic_regression', dual=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1358, in fit
#     self.coef_, self.intercept_, n_iter_ = _fit_liblinear(
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 974, in _fit_liblinear
#     solver_type = _get_liblinear_solver_type(multi_class, penalty, loss, dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 830, in _get_liblinear_solver_type
#     raise ValueError('Unsupported set of arguments: %s, '
# ValueError: Unsupported set of arguments: The combination of penalty='l1' and loss='logistic_regression' are not supported when dual=True, Parameters: penalty='l1', loss='logistic_regression', dual=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1358, in fit
#     self.coef_, self.intercept_, n_iter_ = _fit_liblinear(
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 974, in _fit_liblinear
#     solver_type = _get_liblinear_solver_type(multi_class, penalty, loss, dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 830, in _get_liblinear_solver_type
#     raise ValueError('Unsupported set of arguments: %s, '
# ValueError: Unsupported set of arguments: The combination of penalty='l1' and loss='logistic_regression' are not supported when dual=True, Parameters: penalty='l1', loss='logistic_regression', dual=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1358, in fit
#     self.coef_, self.intercept_, n_iter_ = _fit_liblinear(
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 974, in _fit_liblinear
#     solver_type = _get_liblinear_solver_type(multi_class, penalty, loss, dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 830, in _get_liblinear_solver_type
#     raise ValueError('Unsupported set of arguments: %s, '
# ValueError: Unsupported set of arguments: The combination of penalty='l1' and loss='logistic_regression' are not supported when dual=True, Parameters: penalty='l1', loss='logistic_regression', dual=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1358, in fit
#     self.coef_, self.intercept_, n_iter_ = _fit_liblinear(
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 974, in _fit_liblinear
#     solver_type = _get_liblinear_solver_type(multi_class, penalty, loss, dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 830, in _get_liblinear_solver_type
#     raise ValueError('Unsupported set of arguments: %s, '
# ValueError: Unsupported set of arguments: The combination of penalty='l1' and loss='logistic_regression' are not supported when dual=True, Parameters: penalty='l1', loss='logistic_regression', dual=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 434, in _check_solver
#     raise ValueError("Logistic Regression supports only solvers in %s, got"
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got newton-cholesky.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 434, in _check_solver
#     raise ValueError("Logistic Regression supports only solvers in %s, got"
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got newton-cholesky.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 434, in _check_solver
#     raise ValueError("Logistic Regression supports only solvers in %s, got"
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got newton-cholesky.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 434, in _check_solver
#     raise ValueError("Logistic Regression supports only solvers in %s, got"
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got newton-cholesky.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 434, in _check_solver
#     raise ValueError("Logistic Regression supports only solvers in %s, got"
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got newton-cholesky.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 446, in _check_solver
#     raise ValueError("Solver %s supports only "
# ValueError: Solver saga supports only dual=False, got dual=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 446, in _check_solver
#     raise ValueError("Solver %s supports only "
# ValueError: Solver saga supports only dual=False, got dual=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 446, in _check_solver
#     raise ValueError("Solver %s supports only "
# ValueError: Solver saga supports only dual=False, got dual=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 446, in _check_solver
#     raise ValueError("Solver %s supports only "
# ValueError: Solver saga supports only dual=False, got dual=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 446, in _check_solver
#     raise ValueError("Solver %s supports only "
# ValueError: Solver saga supports only dual=False, got dual=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 434, in _check_solver
#     raise ValueError("Logistic Regression supports only solvers in %s, got"
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got newton-cholesky.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 434, in _check_solver
#     raise ValueError("Logistic Regression supports only solvers in %s, got"
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got newton-cholesky.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 434, in _check_solver
#     raise ValueError("Logistic Regression supports only solvers in %s, got"
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got newton-cholesky.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 434, in _check_solver
#     raise ValueError("Logistic Regression supports only solvers in %s, got"
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got newton-cholesky.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
# ...
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 439, in _check_solver
#     raise ValueError("Logistic Regression supports only penalties in %s,"
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 434, in _check_solver
#     raise ValueError("Logistic Regression supports only solvers in %s, got"
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got newton-cholesky.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 434, in _check_solver
#     raise ValueError("Logistic Regression supports only solvers in %s, got"
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got newton-cholesky.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 434, in _check_solver
#     raise ValueError("Logistic Regression supports only solvers in %s, got"
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got newton-cholesky.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 434, in _check_solver
#     raise ValueError("Logistic Regression supports only solvers in %s, got"
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got newton-cholesky.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 434, in _check_solver
#     raise ValueError("Logistic Regression supports only solvers in %s, got"
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got newton-cholesky.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.88648748        nan        nan        nan        nan
#         nan 0.88648748        nan        nan        nan 0.88648748
#         nan        nan        nan        nan        nan        nan
#  0.88648748 0.88648748 0.88648748        nan 0.88648748 0.88648748
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.89974285        nan        nan        nan        nan
#         nan 0.90234499        nan        nan        nan 0.90231439
#         nan        nan        nan        nan        nan        nan
#  0.89910002 0.89974285 0.89910002        nan 0.89910002 0.89910002
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.90464092        nan        nan        nan        nan
#         nan 0.90868183        nan        nan        nan 0.90892675
#         nan        nan        nan        nan        nan        nan
#  0.90436542 0.90464092 0.90433481        nan 0.90436542 0.90436541
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.90929405        nan        nan        nan        nan
#         nan 0.90963078        nan        nan        nan 0.90956956
#         nan        nan        nan        nan        nan        nan
#  0.9091716  0.90929405 0.90914099        nan 0.9091716  0.9091716
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.90969202        nan        nan        nan        nan
#         nan 0.90953895        nan        nan        nan 0.90944711
#         nan        nan        nan        nan        nan        nan
#  0.90972263 0.9096614  0.90972263        nan 0.90972263 0.90972262
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.90923281        nan        nan        nan        nan
#         nan 0.90950833        nan        nan        nan 0.9094165
#         nan        nan        nan        nan        nan        nan
#  0.90938588 0.90941649 0.90941649        nan 0.9094471  0.90938588]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=LogisticRegression(random_state=14),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'dual': [True, False], 'penalty': ['l1', None, 'l2'],
#                          'random_state': [14],
#                          'solver': ['lbfgs', 'liblinear', 'newton-cg',
#                                     'newton-cholesky', 'sag', 'saga']})

# %%
grid.best_params_
# Out:
# {'C': 10,
#  'dual': False,
#  'penalty': 'l2',
#  'random_state': 14,
#  'solver': 'lbfgs'}

# %%
grid.best_estimator_
# Out:
# LogisticRegression(C=10, random_state=14)

# %%
best_model = grid.best_estimator_
best_model.fit(X_train_sel, y_train)
# Out:
# LogisticRegression(C=10, random_state=14)

# %%
y_pred = best_model.predict(X_train_sel)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
accuracy_score(y_train, y_pred)
# Out:
# 0.909845098879569

# %%
y_pred_test = best_model.predict(X_test_sel)

# %%
y_pred_test
# Out:
# array([0, 0, 0, ..., 0, 1, 0], dtype=int64)

# %%
accuracy_score(y_test,y_pred_test)
# Out:
# 0.9082894575731603

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

bank_cm = confusion_matrix(y_test, y_pred_test)

# Let's draw this matrix to make it more visual
cm_df = pd.DataFrame(bank_cm)

plt.figure(figsize = (3, 3))
sns.heatmap(cm_df, annot=True, fmt="d", cbar=False)

plt.tight_layout()

plt.show()
